# %%
from libs.audio import load_mat_file
from libs.mpl import simple_figure
from libs.path import get_resources_path

# %%
data, max_value = load_mat_file(get_resources_path('digits.mat'), ['digits'])
sampling_frequency = int(10e3)
data.keys()
# Out:
# dict_keys(['digits.zero1', 'digits.zero2', 'digits.one1', 'digits.one2', 'digits.two1', 'digits.two2', 'digits.three1', 'digits.three2', 'digits.four1', 'digits.four2', 'digits.five1', 'digits.five2', 'digits.six1', 'digits.six2', 'digits.seven1', 'digits.seven2', 'digits.eight1', 'digits.eight2', 'digits.nine1', 'digits.nine2'])

# %%
simple_figure(sampling_frequency, data['digits.nine1'])
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
simple_figure(sampling_frequency, data['digits.four1'])
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
simple_figure(sampling_frequency, data['digits.zero2'])
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)
